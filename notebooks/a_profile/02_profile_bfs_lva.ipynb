# %%
# Notebook für Check Daten Profile & Qualität in Bezug auf das Einlesen --> Spaltenlisten ausgeben; Null-Fremdschlüssel zählen

# 1. Schritt: Stimmen Blatt- und Spalten­namen des eingelesenen Excels (nur _Data-Register).

import pandas as pd
from pathlib import Path

excel_path = Path(
    r"C:\Users\claud\iCloudDrive\Dokumente\02_CLI\Studium\ZHAW\Masterarbeit\vocdata\data\bfs_data_lva.xlsx"
)

xls = pd.ExcelFile(excel_path)

for sh in xls.sheet_names:
    if sh.lower().endswith("_data"):
        # Header-Zeile ermitteln: erste Zeile, in der mindestens 3 Zellen nicht leer sind
        top = pd.read_excel(xls, sheet_name=sh, nrows=15, header=None)
        header_row = next(
            i for i, row in top.iterrows() if row.notna().sum() >= 3
        )

        df = pd.read_excel(xls, sheet_name=sh, header=header_row)
        print("=" * 80)
        print(f"▶︎ Sheet: {sh}")
        display(df.head(10))        # zeigt sauber formatiert im Notebook
# Out:
# ...
# ▶︎ Sheet: T1_Lernform_Data
#   abschlussniveau lernform  anzahl_lernende  anzahl_lehrvertraege_lva  \
# 0            EBA      Dual             5955                      1915
# 1            EBA       SOG              199                        57
# 2            EFZ3     Dual            34548                     10723
# 3            EFZ3      SOG             4130                      1590
# 4            EFZ4     Dual            12434                      3545
# 5            EFZ4      SOG             1997                       804
# 6             NaN      NaN            59263                     18634
#
#    anzahl_lernende_lva
# 0                 1526
# 1                   47
# 2                 8458
# 3                 1320
# 4                 2890
# 5                  644
# 6                14885
# ...
# ▶︎ Sheet: T2_Geschlecht_Data
#   abschlussniveau geschlecht  anzahl_lernende  anzahl_lehrvertraege_lva  \
# 0             EBA     Männer           3827.0                    1220.0
# ...

# %%
# %% ------------- DATA_SHEETS neu definieren -------------
import pandas as pd
from pathlib import Path

excel_path = Path(
    r"C:\Users\claud\iCloudDrive\Dokumente\02_CLI\Studium\ZHAW\Masterarbeit\vocdata\data\bfs_data_lva.xlsx"
)
xls = pd.ExcelFile(excel_path)

# alle Register, deren Name auf "_Data" endet
DATA_SHEETS = [s for s in xls.sheet_names if s.endswith("_Data")]
print("DATA_SHEETS =", DATA_SHEETS)   # Kontrolle
# Out:
# DATA_SHEETS = ['T1_Lernform_Data', 'T2_Geschlecht_Data', 'T3_MIG_Status_Data', 'T4_ISCED_Data', 'T4.1_ISCED_EBA_Data', 'T4.2_ISCED_EFZ3_Data', 'T4.3_ISCED_EFZ4_Data', 'T4.1.1_ISCED_Beruf_EBA_Data', 'T4.2.1_ISCED_Beruf_EFZ3_Data', 'T4.3.1_ISCED_Beruf_EFZ4_Data', 'T5_LVA_t_Data', 'T6_Wiedereinstieg_Data', 'T7_Zeitpkt_Wiedereinstieg_Data', 'T8_Geschlecht_Wiedereinst_Data', 'T9_ISCED_Beruf_WEstg_G_Data', 'T9_ISCED_Beruf_WEstg_EBA_Data', 'T9_ISCED_Beruf_WEstg_EFZ3_Data', 'T9_ISCED_Beruf_WEstg_EFZ4_Data', 'T10_Anschlussart_LVA_Data', 'T11_QV_Status_Ende_t_Data', 'T12_QV_Status_Ende_t_sex_Data', 'T13_QV_Status_Ende_t_MIG_Data', 'T14_QV_Status_Ende_t_Beruf_Data']

# %%
# Mapping mit Spalte Datenstatus - Kontrolle Spaltenübersicht pro Blatt – nur einmal zur Orientierung
# ------------------------------------------------------------------
for sh in DATA_SHEETS:
    df = pd.read_excel(xls, sheet_name=sh, nrows=0)   # nur Header einlesen
    print(f"\n=== {sh} ===")
    print(list(df.columns))
# Out:
# === T1_Lernform_Data ===
# ['abschlussniveau', 'lernform', 'anzahl_lernende', 'anzahl_lehrvertraege_lva', 'anzahl_lernende_lva']
#
# === T2_Geschlecht_Data ===
# ['abschlussniveau', 'geschlecht', 'anzahl_lernende', 'anzahl_lehrvertraege_lva', 'anzahl_lernende_lva']
#
# === T3_MIG_Status_Data ===
# ['abschlussniveau', 'mig_status', 'anzahl_lernende', 'anzahl_lehrvertraege_lva', 'anzahl_lernende_lva']
#
# === T4_ISCED_Data ===
# ['abschlussniveau', 'ausbildungsfeld_isced_code', 'ausbildungsfeld_isced_bez', 'anzahl_lernende', 'anzahl_lernende_lva', 'datenstatus']
#
# === T4.1_ISCED_EBA_Data ===
# ['abschlussniveau', 'ausbildungsfeld_isced_code', 'ausbildungsfeld_isced_bez', 'anzahl_lernende', 'anzahl_lernende_lva', 'datenstatus']
#
# === T4.2_ISCED_EFZ3_Data ===
# ['abschlussniveau', 'ausbildungsfeld_isced_code', 'ausbildungsfeld_isced_bez', 'anzahl_lernende', 'anzahl_lernende_lva', 'datenstatus']
#
# === T4.3_ISCED_EFZ4_Data ===
# ...

# %%
# ## Data Quality Check: Anzahl Null-Fremdschlüssel pro Dimension
# %%  ─────────  LVA-Faktentabelle grob prüfen  ─────────
import pandas as pd
from sqlalchemy import create_engine, text

engine = create_engine(
    "mysql+pymysql://root:voc_root@localhost:3306/vocdata",
    echo=False, future=True
)

qry = """
SELECT
    COUNT(*)                                    AS total_rows,
    SUM(abschlussniveau_id  IS NULL)            AS null_abschlussniveau,
    SUM(lernform_id         IS NULL)            AS null_lernform,
    SUM(geschlecht_id       IS NULL)            AS null_geschlecht,
    SUM(mig_status_id       IS NULL)            AS null_mig_status,
    SUM(anschlussart_id     IS NULL)            AS null_anschlussart,
    SUM(qv_status_id        IS NULL)            AS null_qv_status,
    SUM(isced_id            IS NULL)            AS null_isced,
    SUM(beruf_id            IS NULL)            AS null_beruf
FROM fact_lva_stats;
"""

with engine.begin() as con:
    res = con.execute(text(qry)).mappings().one()

print("Null-Fremdschlüssel in fact_lva_stats:")
for k, v in res.items():
    print(f"  {k}: {v}")
# Out:
# Null-Fremdschlüssel in fact_lva_stats:
#   total_rows: 1191
#   null_abschlussniveau: 0
#   null_lernform: 0
#   null_geschlecht: 0
#   null_mig_status: 0
#   null_anschlussart: 0
#   null_qv_status: 0
#   null_isced: 0
#   null_beruf: 0

# %%
# Pfad zum BFS Excel LVA
SRC_FILE = r"C:\Users\claud\iCloudDrive\Dokumente\02_CLI\Studium\ZHAW\Masterarbeit\vocdata\data\bfs_data_lva.xlsx"   
xls = pd.ExcelFile(SRC_FILE)

print("Quelle gesetzt:", SRC_FILE)
# Out:
# Quelle gesetzt: C:\Users\claud\iCloudDrive\Dokumente\02_CLI\Studium\ZHAW\Masterarbeit\vocdata\data\bfs_data_lva.xlsx

# %%
targets = [s for s in xls.sheet_names if s.startswith(("T4", "T9", "T25"))]
print("Gefundene Blätter:", targets)
# Out:
# Gefundene Blätter: ['T4_ISCED_Data', 'T4.1_ISCED_EBA_Data', 'T4.2_ISCED_EFZ3_Data', 'T4.3_ISCED_EFZ4_Data', 'T4_ISCED_Dict', 'T4.1.1_ISCED_Beruf_EBA_Data', 'T4.2.1_ISCED_Beruf_EFZ3_Data', 'T4.3.1_ISCED_Beruf_EFZ4_Data', 'T4.1._ISCED_Beruf_Dict', 'T9_ISCED_Beruf_WEstg_G_Data', 'T9_ISCED_Beruf_WEstg_EBA_Data', 'T9_ISCED_Beruf_WEstg_EFZ3_Data', 'T9_ISCED_Beruf_WEstg_EFZ4_Data', 'T9_ISCED_Beruf_W-Einstieg_Dict']

# %%
# ------------------------------------------------------------------
# 1) Excel Tabs mit Daten (Suffix Data)
# ------------------------------------------------------------------
DATA_SHEETS = [s for s in targets if s.endswith("_Data")]
print("DATA_SHEETS =", DATA_SHEETS)

# ------------------------------------------------------------------
# 2) Schnell-Vorschau – erste drei Zeilen je Blatt
# ------------------------------------------------------------------
for sh in DATA_SHEETS:
    df = pd.read_excel(xls, sheet_name=sh, nrows=3)
    print(f"\n=== {sh} ===")
    display(df)
# Out:
# DATA_SHEETS = ['T4_ISCED_Data', 'T4.1_ISCED_EBA_Data', 'T4.2_ISCED_EFZ3_Data', 'T4.3_ISCED_EFZ4_Data', 'T4.1.1_ISCED_Beruf_EBA_Data', 'T4.2.1_ISCED_Beruf_EFZ3_Data', 'T4.3.1_ISCED_Beruf_EFZ4_Data', 'T9_ISCED_Beruf_WEstg_G_Data', 'T9_ISCED_Beruf_WEstg_EBA_Data', 'T9_ISCED_Beruf_WEstg_EFZ3_Data', 'T9_ISCED_Beruf_WEstg_EFZ4_Data']
#
# === T4_ISCED_Data ===
#   abschlussniveau  ausbildungsfeld_isced_code  \
# 0  Total_Lernende                         211
# 1  Total_Lernende                         212
# 2  Total_Lernende                         214
#
#                          ausbildungsfeld_isced_bez  anzahl_lernende  \
# 0     Audiovisuelle Techniken und Medienproduktion              779
# 1  Mode, Innenarchitektur und industrielles Design              212
# 2                                    Kunsthandwerk              212
#
#    anzahl_lernende_lva datenstatus
# 0                  199          OK
# 1                   39          OK
# 2                   66          OK
# ...

# %%
# Qualitäts-Check: Werden alle *_Data-Blätter gelesen?
from pathlib import Path
import pandas as pd

xls = pd.ExcelFile(Path("../data/bfs_data_lva.xlsx"))
for sh in xls.sheet_names:
    if sh.lower().endswith("_data"):
        df = pd.read_excel(xls, sheet_name=sh)
        print(f"✓ {sh}: {len(df)} Zeilen (Excel)")
# Out:
# ✓ T1_Lernform_Data: 7 Zeilen (Excel)
# ✓ T2_Geschlecht_Data: 9 Zeilen (Excel)
# ✓ T3_MIG_Status_Data: 13 Zeilen (Excel)
# ✓ T4_ISCED_Data: 31 Zeilen (Excel)
# ✓ T4.1_ISCED_EBA_Data: 20 Zeilen (Excel)
# ✓ T4.2_ISCED_EFZ3_Data: 30 Zeilen (Excel)
# ✓ T4.3_ISCED_EFZ4_Data: 18 Zeilen (Excel)
# ✓ T4.1.1_ISCED_Beruf_EBA_Data: 55 Zeilen (Excel)
# ✓ T4.2.1_ISCED_Beruf_EFZ3_Data: 106 Zeilen (Excel)
# ✓ T4.3.1_ISCED_Beruf_EFZ4_Data: 67 Zeilen (Excel)
# ✓ T5_LVA_t_Data: 12 Zeilen (Excel)
# ✓ T6_Wiedereinstieg_Data: 6 Zeilen (Excel)
# ✓ T7_Zeitpkt_Wiedereinstieg_Data: 9 Zeilen (Excel)
# ✓ T8_Geschlecht_Wiedereinst_Data: 6 Zeilen (Excel)
# ✓ T9_ISCED_Beruf_WEstg_G_Data: 207 Zeilen (Excel)
# ✓ T9_ISCED_Beruf_WEstg_EBA_Data: 48 Zeilen (Excel)
# ✓ T9_ISCED_Beruf_WEstg_EFZ3_Data: 98 Zeilen (Excel)
# ✓ T9_ISCED_Beruf_WEstg_EFZ4_Data: 61 Zeilen (Excel)
# ✓ T10_Anschlussart_LVA_Data: 24 Zeilen (Excel)
# ✓ T11_QV_Status_Ende_t_Data: 12 Zeilen (Excel)
# ✓ T12_QV_Status_Ende_t_sex_Data: 24 Zeilen (Excel)
# ...

# %%
#Die Faktentabelle fact_lva_stats ist vollständig geladen

# %%
# %% ---------- Vollständigkeits-Audit fact_lva_stats ----------
import pandas as pd
from sqlalchemy import text

qry = """
SELECT
  COUNT(*)                                      AS total_rows,

  -- Kennzahlen auf NULL prüfen
  SUM(anzahl_lernende_lva            IS NULL)   AS null_lernende_lva,
  SUM(anzahl_lernende_wiedereinstieg IS NULL)   AS null_wiedereinstieg,
  SUM(anzahl_lernende               IS NULL)    AS null_lernende,
  SUM(anzahl_lehrvertraege_lva       IS NULL)   AS null_lehrvertraege_lva,
  SUM(anzahl_lehrvertraege           IS NULL)   AS null_lehrvertraege,

  -- FK-IDs auf 0 (UNKNOWN) prüfen
  SUM(abschlussniveau_id   = 0) AS fk_abschl_niv,
  SUM(lernform_id          = 0) AS fk_lernform,
  SUM(geschlecht_id        = 0) AS fk_geschlecht,
  SUM(mig_status_id        = 0) AS fk_mig_status,
  SUM(anschlussart_id      = 0) AS fk_anschlussart,
  SUM(qv_status_id         = 0) AS fk_qv_status,
  SUM(lva_zeitraum_id      = 0) AS fk_lva_zeitraum,
  SUM(wiedereinst_dauer_id = 0) AS fk_wieder_dauer,
  SUM(isced_id             = 0) AS fk_isced,
  SUM(beruf_id             = 0) AS fk_beruf
FROM fact_lva_stats;
"""

audit = pd.read_sql(text(qry), engine)
display(audit.T)   # transponiert = übersichtlicher
# Out:
#                              0
# total_rows              1191.0
# null_lernende_lva        669.0
# null_wiedereinstieg      998.0
# null_lernende            510.0
# null_lehrvertraege_lva  1165.0
# null_lehrvertraege      1191.0
# fk_abschl_niv            240.0
# fk_lernform             1185.0
# fk_geschlecht           1155.0
# fk_mig_status           1131.0
# fk_anschlussart         1167.0
# fk_qv_status             827.0
# fk_lva_zeitraum         1179.0
# fk_wieder_dauer         1182.0
# fk_isced                 170.0
# fk_beruf                 549.0

# %%
# %%  ─────────  Quick-Profil nach Excel-Überarbeitung  ─────────
from pathlib import Path
import pandas as pd

excel_path = Path("../data/bfs_data_lva.xlsx")   # ggf. Pfad prüfen
xls = pd.ExcelFile(excel_path)

print("Gefundene Sheets:", xls.sheet_names, "\n")

for sheet in xls.sheet_names:
    if sheet.endswith("_Data"):
        df = pd.read_excel(xls, sheet_name=sheet, nrows=5)   # nur Vorschau
        print(f"--- {sheet} ---")
        display(df.head(3))
# Out:
# Gefundene Sheets: ['T1_Lernform_Data', 'T1_Lernform_Dict', 'T2_Geschlecht_Data', 'T2_Geschlecht_Dict', 'T3_MIG_Status_Data', 'T3_MIG_Status_Dict', 'T4_ISCED_Data', 'T4.1_ISCED_EBA_Data', 'T4.2_ISCED_EFZ3_Data', 'T4.3_ISCED_EFZ4_Data', 'T4_ISCED_Dict', 'T4.1.1_ISCED_Beruf_EBA_Data', 'T4.2.1_ISCED_Beruf_EFZ3_Data', 'T4.3.1_ISCED_Beruf_EFZ4_Data', 'T4.1._ISCED_Beruf_Dict', 'T5_LVA_t_Data', 'T5_LVA_t_Dict', 'T6_Wiedereinstieg_Data', 'T6_Wiedereinstieg_Dict', 'T7_Zeitpkt_Wiedereinstieg_Data', 'T7_Zeitpkt_Wiederein_Dict', 'T8_Geschlecht_Wiedereinst_Data', 'T8_Geschlecht_Wiedereinst_Dict', 'T9_ISCED_Beruf_WEstg_G_Data', 'T9_ISCED_Beruf_WEstg_EBA_Data', 'T9_ISCED_Beruf_WEstg_EFZ3_Data', 'T9_ISCED_Beruf_WEstg_EFZ4_Data', 'T9_ISCED_Beruf_W-Einstieg_Dict', 'T10_Anschlussart_LVA_Data', 'T10_Anschlussart_LVA_Dict', 'T11_QV_Status_Ende_t_Data', 'T11_QV_Status_Ende_t_Dict', 'T12_QV_Status_Ende_t_sex_Data', 'T12_QV_Status_Ende_t_sex_Dict', 'T13_QV_Status_Ende_t_MIG_Data', 'T13_QV_Status_Ende_t_MIG_D
# ...

# %%
# %% -------------  Audit Es wurden Flags für LVA & Wiedereinstiegsdaten gesetzt und eine Dimenesion "Kohorte" angelegt - > hier Audit Flags + Kohorte -------------
# Zunächst fehlerhaft, Anzeige von 1 bei Wiedereinstieg ohne LVA, Datenbereinigung erfolgte, danach OK
import pandas as pd
from sqlalchemy import create_engine, text

engine = create_engine(
    "mysql+pymysql://root:voc_root@localhost:3306/vocdata",
    future=True, echo=False
)

sql = """
SELECT
    kohorte_id,
    is_lva,
    is_wiedereinstieg,
    COUNT(*) AS zeilen
FROM fact_lva_stats
GROUP BY kohorte_id, is_lva, is_wiedereinstieg
ORDER BY kohorte_id, is_lva, is_wiedereinstieg;
"""
pd.read_sql(text(sql), engine)
# Out:
#    kohorte_id  is_lva  is_wiedereinstieg  zeilen
# 0           1       0                  0     111
# 1           1       1                  0     887
# 2           1       1                  1     193

# %%
# %% --------Da Umbennenugn der Spalten im Excel (ursprüngliche Inkonsistenz beseitigt) --> Fehler im Code, daher Kontrolle via Script & Abgleich Spaltenabgleich Tabelle ↔ Excel --------
import pandas as pd
from sqlalchemy import create_engine
from pathlib import Path

engine = create_engine("mysql+pymysql://root:voc_root@localhost:3306/vocdata", echo=False)
excel_file = Path("../data/bfs_data_lva.xlsx")   # falls Pfad anders: anpassen

# 1) Spalten der MySQL-Tabelle
db_cols = pd.read_sql("SELECT * FROM fact_lva_stats LIMIT 0", engine).columns

# 2) Alle Kopfzeilen aus *allen* *_Data-Blättern
xls = pd.ExcelFile(excel_file)
excel_cols = set()
for sh in xls.sheet_names:
    if sh.lower().endswith("_data"):
        df_head = pd.read_excel(xls, sheet_name=sh, nrows=5)   # reicht für Header
        excel_cols.update(c.strip() for c in df_head.columns)

# 3) Vergleich
only_in_db   = sorted(set(db_cols)  - excel_cols)
only_in_xls  = sorted(excel_cols    - set(db_cols))

print("Nur in Datenbank:", only_in_db)
print("Nur im Excel   :", only_in_xls)
# Out:
# Nur in Datenbank: ['abschlussniveau_id', 'anschlussart_id', 'anzahl_lehrvertraege', 'anzahl_lva_vertraege', 'beruf_id', 'fact_id', 'geschlecht_id', 'is_lva', 'is_wiedereinstieg', 'isced_id', 'kohorte_id', 'lernform_id', 'lva_zeitraum_id', 'mig_status_id', 'qv_status_id', 'total_lernende', 'wiedereinst_dauer_id']
# Nur im Excel   : ['abschlussniveau', 'ausbildungsfeld_isced_bez', 'ausbildungsfeld_isced_code', 'beruf_bez', 'geschlecht', 'lernform', 'lva_anschlussart', 'lva_zeitpunkt', 'mig_status', 'qv_status', 'wiedereinstieg', 'wiedereinstieg_dauer']
