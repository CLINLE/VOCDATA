# %%
# %% ─────────────────────  INITIALISIERUNG  ─────────────────────
import pandas as pd
from pathlib import Path

SRC_FILE = Path("../../data/bfs_data_abschlussquote.xlsx")    # relativer Pfad 
xls = pd.ExcelFile(SRC_FILE)

DATA_SHEETS = [s for s in xls.sheet_names if s.endswith("_Data")]
print("DATA_SHEETS =", DATA_SHEETS)

# %% ───────── Sheet-Profilierung: Vorschau & Info ─────────
summary = []                        # für die Schluss-Tabelle

for sheet in DATA_SHEETS:
    # Header automatisch finden (erste Zeile mit ≥3 Werten)
    head = pd.read_excel(xls, sheet_name=sheet, nrows=15, header=None)
    header_row = next(i for i, r in head.iterrows() if r.notna().sum() >= 3)

    df = pd.read_excel(xls, sheet_name=sheet, header=header_row)

    print(f"\n=== {sheet} ===")
    display(df.head(5))             # Vorschau
    print(df.info())                # Datentypen & Null-Zellen

    summary.append({
        "sheet": sheet,
        "rows": len(df),
        "cols": len(df.columns),
        "nulls_total": df.isna().sum().sum()
    })

# %% ───────── Gesamt-Übersicht ─────────
profil = pd.DataFrame(summary)
display(profil)
# Out:
# DATA_SHEETS = ['T1_SekII_1st_25_Merkm_Data', 'T2_SekII_1st_25_Kant_Data', 'T3_Matura_Merkm_Data', 'T4_Matura_Kant_Data']
#
# === T1_SekII_1st_25_Merkm_Data ===
#    jahr              merkmal                                kategorie  \
# 0  2022                Total                                      NaN
# 1  2022           Geschlecht                                   Männer
# 2  2022           Geschlecht                                   Frauen
# 3  2022  Migrationskategorie  in der Schweiz geborene Schweizer/innen
# 4  2022  Migrationskategorie  in der Schweiz geborene Ausländer/innen
#
#    total_anz_25J  total_anz_sekII_erstabschluss_25J  \
# 0          80423                              72437
# 1          41437                              36684
# 2          39018                              35753
# 3          60557                              55798
# 4           7745                               6587
#
# ...
