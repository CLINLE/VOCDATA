# %%
import pandas as pd
from pathlib import Path

excel_path = Path(r"C:\Users\claud\iCloudDrive\Dokumente\02_CLI\Studium\ZHAW\Masterarbeit\vocdata\data\bfs_data_abschlussquote.xlsx")
xls = pd.ExcelFile(excel_path)

print("Gefundene Sheets:", xls.sheet_names, "\n")

for sheet in xls.sheet_names:
    if sheet.endswith("_Data"):
        df = pd.read_excel(xls, sheet_name=sheet, nrows=10)
        print(f"--- {sheet} ---")
        display(df)
# Out:
# Gefundene Sheets: ['T1_SekII_1st_25_Merkm_Data', 'T1_SekII_1st_25_Merkm_Dict', 'T2_SekII_1st_25_Kant_Data', 'T2_SekII_1st_25_Kant_Dict.', 'T3_Matura_Merkm_data', 'T3_Matura_Merk_dict', 'T4_Matura_Kant_data', 'T4_Matura_Kant_dict']
#
# --- T1_SekII_1st_25_Merkm_Data ---
#    jahr              merkmal                                    kategorie  \
# 0  2022                Total                                          NaN
# 1  2022           Geschlecht                                       Männer
# 2  2022           Geschlecht                                       Frauen
# 3  2022  Migrationskategorie      in der Schweiz geborene Schweizer/innen
# 4  2022  Migrationskategorie      in der Schweiz geborene Ausländer/innen
# 5  2022  Migrationskategorie          im Ausland geborene Schweizer/innen
# 6  2022  Migrationskategorie          im Ausland geborene Ausländer/innen
# 7  2022         Sprachregion  deutschsprachige und rätoromanische Schweiz
# ...
